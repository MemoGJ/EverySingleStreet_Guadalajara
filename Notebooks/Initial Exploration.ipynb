# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# read data
df = pd.read_csv(r'C:\Users\Hector G. Guerrero\Documents\Portfolio\EverySingleStreetGDL\all_data.csv')
df_all = pd.read_csv(r'C:\Users\Hector G. Guerrero\Documents\Portfolio\EverySingleStreetGDL\Activities.csv')

# %%
df.dtypes
# Out:
# Activity ID           int64
# Time                 object
# LatitudeDegrees     float64
# LongitudeDegrees    float64
# AltitudeMeters      float64
# DistanceMeters      float64
# HeartRateBpm        float64
# Speed               float64
# RunCadence          float64
# dtype: object

# %%
df.nunique()
# Out:
# Activity ID            209
# Time                327311
# LatitudeDegrees     288603
# LongitudeDegrees    294123
# AltitudeMeters        1247
# DistanceMeters      299954
# HeartRateBpm           146
# Speed                  541
# RunCadence             110
# dtype: int64

# %%
df.sample(5)
# Out:
#         Activity ID                      Time  LatitudeDegrees  \
# 243607   7079532607  2021-07-06T13:09:38.000Z        20.685005
# 318962   7597590038  2021-10-03T16:22:09.000Z        20.654520
# 34160    5744490682  2020-10-29T13:49:44.000Z        20.699147
# 304505   7534460613  2021-09-22T14:24:51.000Z        20.637031
# 259202   7221770794  2021-07-31T13:39:55.000Z        20.662045
#
#         LongitudeDegrees  AltitudeMeters  DistanceMeters  HeartRateBpm  Speed  \
# 243607       -103.289886     1528.000000     5742.629883         140.0  3.564
# 318962       -103.273130     1571.599976    37294.460938         185.0  3.070
# 34160        -103.358946     1556.199951     5644.390137           NaN  2.575
# 304505       -103.319814     1569.400024    14203.320312         173.0  3.816
# 259202       -103.318121     1554.599976     3449.030029         158.0  3.098
#
#         RunCadence
# 243607        85.0
# 318962        84.0
# 34160         85.0
# 304505        85.0
# ...

# %%
pd.set_option('display.max_columns', None)

df_all.sample(5)
# Out:
#                     Start Time                   End Time  Activity ID  \
# 98   2021-03-13T06:57:24+18:00  2021-03-13T10:30:49+18:00   6423379294
# 106  2021-02-26T07:03:15+18:00  2021-02-26T09:03:36+18:00   6337542876
# 45   2021-07-18T07:59:17+19:00  2021-07-18T11:04:40+19:00   7147608919
# 62   2021-06-16T07:40:13+19:00  2021-06-16T09:08:08+19:00   6968817566
# 208  2020-10-02T06:24:09+19:00  2020-10-02T08:13:19+19:00   5621493235
#
#                               Activity Name  Description Location Name  \
# 98               111. ESS GDL Del Fresno II          NaN   Guadalajara
# 106                 103. ESS GDL La Moderna          NaN   Guadalajara
# 45   164. ESS GDL Mexicaltzingo, La Moderna          NaN   Guadalajara
# 62           147. ESS GDL Río Verde, Tetlán          NaN   Guadalajara
# 208                               ESS GDL 1          NaN   Guadalajara
#
#            Time Zone  Offset Duration (h:m:s) Elapsed Duration (h:m:s)  \
# ...
